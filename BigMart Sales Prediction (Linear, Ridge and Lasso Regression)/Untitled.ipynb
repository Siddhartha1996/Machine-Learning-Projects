# %%
import pandas as pd
import numpy as np
df_test =  pd.read_csv(r'Test.csv')
df_train =  pd.read_csv(r'Train.csv')

# %%
df_test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
df_train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df_test.shape
# Out:
# (5681, 11)

# %%
df_train.shape
# Out:
# (8523, 12)

# %%
df_test[df_test.isnull().any(axis=1)]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# 7              FDC48          NaN          Low Fat         0.015782
# ...              ...          ...              ...              ...
# 5669           FDN31          NaN          Low Fat         0.072529
# 5670           FDO03       10.395          Regular         0.037092
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 1                     Dairy   87.3198            OUT017
# ...

# %%
df_train[df_train.isnull().any(axis=1)]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07        19.20          Regular         0.000000
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17        16.20          Regular         0.016687
# 9              FDU28        19.20          Regular         0.094450
# 18             DRI11          NaN          Low Fat         0.034238
# ...              ...          ...              ...              ...
# 8504           NCN18          NaN          Low Fat         0.124111
# 8508           FDW31        11.35          Regular         0.043246
# 8509           FDG45         8.10          Low Fat         0.214306
# 8514           FDA01        15.00          Regular         0.054489
# 8519           FDS36         8.38          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# ...

# %%
df_train['Item_Weight'].fillna((df_train['Item_Weight'].mean()), inplace=True)
df_train['Item_Visibility'].fillna((df_train['Item_Visibility'].mean()), inplace=True)
df_train['Item_MRP'].fillna((df_train['Item_MRP'].mean()), inplace=True)
df_train['Item_Outlet_Sales'].fillna((df_train['Item_Outlet_Sales'].mean()), inplace=True)
df_train['Item_Fat_Content'].fillna((df_train['Item_Fat_Content'].mode()), inplace=True)
df_train['Item_Type'].fillna((df_train['Item_Type'].mode()), inplace=True)
df_train['Item_Fat_Content'].fillna((df_train['Item_Fat_Content'].mode()), inplace=True)
df_train['Outlet_Identifier'].fillna((df_train['Outlet_Identifier'].mode()), inplace=True)
df_train['Outlet_Establishment_Year'].fillna((df_train['Outlet_Establishment_Year'].mode()), inplace=True)
df_train['Outlet_Establishment_Year'].fillna((df_train['Outlet_Establishment_Year'].mode()), inplace=True)
df_train['Outlet_Size'].fillna(('Medium'), inplace=True)
df_train['Outlet_Location_Type'].fillna((df_train['Outlet_Location_Type'].mode()), inplace=True)
df_train['Outlet_Type'].fillna((df_train['Outlet_Type'].mode()), inplace=True)

# %%
df_train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df_train = df_train.drop(['Item_Identifier', 'Outlet_Identifier'], axis = 1)
df_train
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %% [markdown]
# Now that we have dealt with NaN in the Data by using Means and Modes, we can proceed with one hot encoder.

# %%
df_test['Item_Weight'].fillna((df_test['Item_Weight'].mean()), inplace=True)
df_test['Item_Visibility'].fillna((df_test['Item_Visibility'].mean()), inplace=True)
df_test['Item_MRP'].fillna((df_test['Item_MRP'].mean()), inplace=True)
df_test['Item_Fat_Content'].fillna((df_test['Item_Fat_Content'].mode()), inplace=True)
df_test['Item_Type'].fillna((df_test['Item_Type'].mode()), inplace=True)
df_test['Item_Fat_Content'].fillna((df_test['Item_Fat_Content'].mode()), inplace=True)
df_test['Outlet_Identifier'].fillna((df_test['Outlet_Identifier'].mode()), inplace=True)
df_test['Outlet_Establishment_Year'].fillna((df_test['Outlet_Establishment_Year'].mode()), inplace=True)
df_test['Outlet_Establishment_Year'].fillna((df_test['Outlet_Establishment_Year'].mode()), inplace=True)
df_test['Outlet_Size'].fillna(('Medium'), inplace=True)
df_test['Outlet_Location_Type'].fillna((df_test['Outlet_Location_Type'].mode()), inplace=True)
df_test['Outlet_Type'].fillna((df_test['Outlet_Type'].mode()), inplace=True)

# %%
df_test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58    20.750000          Low Fat         0.007565
# 1              FDW14     8.300000              reg         0.038428
# 2              NCN55    14.600000          Low Fat         0.099575
# 3              FDQ58     7.315000          Low Fat         0.015388
# 4              FDY38    12.695633          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58    10.500000          Regular         0.013496
# 5677           FDD47     7.600000          Regular         0.142991
# 5678           NCO17    10.000000          Low Fat         0.073529
# 5679           FDJ26    15.300000          Regular         0.000000
# 5680           FDU37     9.500000          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
df_test = df_test.drop(['Item_Identifier', 'Outlet_Identifier'], axis = 1)

# %%
df_test
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 0       20.750000          Low Fat         0.007565         Snack Foods
# 1        8.300000              reg         0.038428               Dairy
# 2       14.600000          Low Fat         0.099575              Others
# 3        7.315000          Low Fat         0.015388         Snack Foods
# 4       12.695633          Regular         0.118599               Dairy
# ...           ...              ...              ...                 ...
# 5676    10.500000          Regular         0.013496         Snack Foods
# 5677     7.600000          Regular         0.142991       Starchy Foods
# 5678    10.000000          Low Fat         0.073529  Health and Hygiene
# 5679    15.300000          Regular         0.000000              Canned
# 5680     9.500000          Regular         0.104720              Canned
#
#       Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# ...

# %%
df_train.describe
# Out:
# <bound method NDFrame.describe of       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 3))
plt.hist(df_train['Item_Outlet_Sales'])
plt.xlabel('')
plt.ylabel('Outlet Sales')
plt.tight_layout()

# %%
import seaborn as sns
sns.pairplot(df_train)

# %%
df_train.boxplot(column='Item_Weight', by='Outlet_Type')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,12))
sns.heatmap(df_train.corr(),annot=True,cmap='Blues')

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %%
le = LabelEncoder()
df_train['Item_Fat_Content'] = le.fit_transform(df_train['Item_Fat_Content'])
df_train['Item_Type'] = le.fit_transform(df_train['Item_Type'])
df_train['Outlet_Size'] = le.fit_transform(df_train['Outlet_Size'])
df_train['Outlet_Type'] = le.fit_transform(df_train['Outlet_Type'])
df_train['Outlet_Location_Type'] = le.fit_transform(df_train['Outlet_Location_Type'])

# %%
#dummy = pd.get_dummies(df_train['Outlet_Size'])
#dummy.head()
df_train
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0           9.300                 1         0.016047          4  249.8092
# 1           5.920                 2         0.019278         14   48.2692
# 2          17.500                 1         0.016760         10  141.6180
# 3          19.200                 2         0.000000          6  182.0950
# 4           8.930                 1         0.000000          9   53.8614
# ...           ...               ...              ...        ...       ...
# 8518        6.865                 1         0.056783         13  214.5218
# 8519        8.380                 2         0.046982          0  108.1570
# 8520       10.600                 1         0.035186          8   85.1224
# 8521        7.210                 2         0.145221         13  103.1332
# 8522       14.800                 1         0.044878         14   75.4670
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# ...

# %%
df_test['Item_Fat_Content'] = le.fit_transform(df_test['Item_Fat_Content'])
df_test['Item_Type'] = le.fit_transform(df_test['Item_Type'])
df_test['Outlet_Size'] = le.fit_transform(df_test['Outlet_Size'])
df_test['Outlet_Type'] = le.fit_transform(df_test['Outlet_Type'])
df_test['Outlet_Location_Type'] = le.fit_transform(df_test['Outlet_Location_Type'])

# %%
lin = LinearRegression()

# %%
X = df_train.drop('Item_Outlet_Sales', axis=1)
y = df_train.Item_Outlet_Sales

# %%
X
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0           9.300                 1         0.016047          4  249.8092
# 1           5.920                 2         0.019278         14   48.2692
# 2          17.500                 1         0.016760         10  141.6180
# 3          19.200                 2         0.000000          6  182.0950
# 4           8.930                 1         0.000000          9   53.8614
# ...           ...               ...              ...        ...       ...
# 8518        6.865                 1         0.056783         13  214.5218
# 8519        8.380                 2         0.046982          0  108.1570
# 8520       10.600                 1         0.035186          8   85.1224
# 8521        7.210                 2         0.145221         13  103.1332
# 8522       14.800                 1         0.044878         14   75.4670
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# ...

# %%
y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
X_test = df_test

# %% [markdown]
# # Let's have a look at Real Sales:

# %%
df_real =  pd.read_csv(r'Submission.csv')
df_real.head()
# Out:
#    Unnamed: 0 Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0           0           FDW58            OUT049        1636.244023
# 1           1           FDW14            OUT017        1409.355910
# 2           2           NCN55            OUT010         710.594286
# 3           3           FDQ58            OUT017        2355.184955
# 4           4           FDY38            OUT027        5857.916205

# %%
df_real = df_real['Item_Outlet_Sales']
df_real = df_real.to_numpy()
df_real
# Out:
# array([1636.24402324, 1409.35591001,  710.59428649, ..., 1832.45135758,
#        3538.68518843, 1281.1444623 ])

# %% [markdown]
# # Let us do Linear Regression:

# %%
from sklearn.linear_model import LinearRegression
lin = LinearRegression()
lin.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predictions = lin.predict(X_test)

# %%
predictions
# Out:
# array([2053.19024907, 1386.5962468 , 2169.52198641, ..., 1723.60408523,
#        3364.15740379, 1105.75293969])

# %%
from sklearn.model_selection import cross_val_predict
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
# The coefficients
print('Coefficients: \n', lin.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(df_real, predictions))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(df_real, predictions))
# Out:
# Coefficients:
#  [-1.01651389e+00  2.95650971e+01 -1.47374004e+03 -1.13440852e+00
#   1.56010128e+01  1.31018628e+00 -3.33772536e+02 -4.22670008e+02
#   9.98784078e+02]
# Mean squared error: 252280.37
# Coefficient of determination: 0.85

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X, y)
predicted = clf.predict(X_test)
expected = y
plt.figure(figsize=(8, 6))
plt.scatter(df_real, predictions)
plt.plot([0, 50], [0, 50], '--k')
plt.axis('tight')
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.tight_layout()

# %% [markdown]
# # Let's use Ridge Regression:

# %%
from sklearn.linear_model import Ridge
clf = Ridge(alpha=0.5)
clf.fit(X, y)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
predictions_Ridge = clf.predict(X_test)

# %%
predictions_Ridge
# Out:
# array([2051.54585076, 1385.57268726, 2170.22160439, ..., 1723.95238368,
#        3362.05421434, 1106.98411938])

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df_real, predictions_Ridge)
plt.plot([0, 50], [0, 50], '--k')
plt.axis('tight')
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.tight_layout()

# %% [markdown]
# # Lasso Regression:

# %%
from sklearn import linear_model
clf = linear_model.Lasso(alpha=0.2)

# %%
clf.fit(X,y)
# Out:
# Lasso(alpha=0.2, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
predictions_Lasso = clf.predict(X_test)

# %%
predictions_Lasso
# Out:
# array([2048.55970583, 1382.63753445, 2172.3436233 , ..., 1724.28765804,
#        3358.64856691, 1108.01729764])

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df_real, predictions_Lasso)
plt.plot([0, 50], [0, 50], '--k')
plt.axis('tight')
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.tight_layout()

# %% [markdown]
# # Let's Have a look at actual sales:

# %%
df_real =  pd.read_csv(r'Submission.csv')

# %%
df_real

# %%
df_real = df_real['Item_Outlet_Sales']

# %%
df_real

# %%
df_real = df_real.to_numpy()

# %%
df_real

# %%
=
